# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Data/initial_data.xlsx')
data
# Out:
#             date      time  temp (C)  gas (ohm)  humidity (%)  pressure (hPa)  \
# 0     2022-03-16  21:27:25      23.9       7795          15.3        1035.755
# 1     2022-03-16  21:35:44      23.9       6582          15.3        1035.780
# 2     2022-03-16  21:35:56      23.9       5703          15.3        1035.815
# 3     2022-03-16  21:38:56      23.9       1268          15.3        1035.820
# 4     2022-03-16  21:41:56      23.9       1949          15.4        1035.824
# ...          ...       ...       ...        ...           ...             ...
# 55626 2022-04-09  17:01:10      22.1    1186891          19.0         992.727
# 55627 2022-04-09  17:01:12      22.2      43303          19.0         992.725
# 55628 2022-04-09  17:01:13      22.2      45661          19.0         992.729
# 55629 2022-04-09  17:01:14      22.3      51183          19.0         992.732
# 55630 2022-04-09  17:03:01      22.2     409627          19.0         992.728
#
# ...

# %%
labels = ['Bad', 'Middle', 'Good']

# %%
data.total.value_counts()
# Out:
# Middle    29201
# Bad       14032
# Good      12398
# Name: total, dtype: int64

# %%
fig = plt.figure(figsize=(10, 8))
ax = plt.subplot(111)
data.total.value_counts().plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=270, fontsize=17)
plt.savefig('./Pictures/pie_total.png', bbox_inches='tight')
fig.show()
# Out:
# C:\Users\gto_n\anaconda3\envs\masters_work\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """
